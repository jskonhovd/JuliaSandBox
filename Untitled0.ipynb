# %%
x = pi -sin(4)
3x^2 + 2x - 5
# Out:
# 48.3892445086433

# %%
using PyPlot
# Out:
# Loading help data...

# %%
x = linspace(0 ,2pi, 1000)
y = sin(3x + 4cos(2x))
plot(x, y, color="red", linewidth=2.0, linestyle="--")
title("Plot of an Oscillatory function")
xlabel("the x axis")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1469E3F0>)
# PyObject <matplotlib.text.Text object at 0x1469ED90>
